# %% [markdown]
# # Model I/O

# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
from langchain_openai import ChatOpenAI

# %%
chat = ChatOpenAI(model="gpt-4", max_tokens=100, seed=365, temperature=0)

# %%
result = chat.invoke(''' I've recently adopted a dog. Could you suggest some dog names? ''')
print(result.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 result = chat.invoke(''' I've recently adopted a dog. Could you suggest some dog names? ''')
#       2 print(result.content)
#
# NameError: name 'chat' is not defined

# %%
# System and Human
