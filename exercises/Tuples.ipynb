# %% [markdown]
# ### Tuples

# %%
fruits = ('Apple', 'Banana')
print(fruits)
print("-"*55)
print(type(fruits))
print("-"*55)
print(dir(fruits))
# Out:
# ('Apple', 'Banana')
# -------------------------------------------------------
# <class 'tuple'>
# -------------------------------------------------------
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']

# %%
x = (40, 41, 42)
x
# Out:
# (40, 41, 42)

# %%
type(x)
# Out:
# tuple

# %%
x[0]
# Out:
# 40

# %%
# x[0] = 25 ---> TypeError: 'tuple' object does not support item assignment

# %%
x.index(42)
# Out:
# 2

# %%
x.count(41)
# Out:
# 1

# %%
def square(x):
    result = x ** 2
    print(f"Square of {x} is {result}.")
    return x, result

square(5)
# Out:
# Square of 5 is 25.
# (5, 25)

# %%
fruits = 'Apple', 'Banana'
tropical = ('Durian', 'Rambutan')
list_of_fruits = [fruits, tropical]
list_of_fruits
# Out:
# [('Apple', 'Banana'), ('Durian', 'Rambutan')]

# %%
list_of_fruits[0][1]
# Out:
# 'Banana'
