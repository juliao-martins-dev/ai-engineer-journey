# %%
x1 = 5

# %%
type(x1)
# Out:
# int

# %%
x2 = 3.14

# %%
type(x2)
# Out:
# float

# %%
x3 = 17j

# %%
type(x3)
# Out:
# complex

# %%
x4 = int(x2)

# %%
type(x4)
# Out:
# int

# %%
x5 = True

# %%
type(x5)
# Out:
# bool

# %%
is_staff = False

# %%
is_staff
# Out:
# False

# %%
type(is_staff)
# Out:
# bool
