# %%
dict = {"k1": "cat", "k2": "dog", "k3": "mouse", "k4": "fish"}
dict
# Out:
# {'k1': 'cat', 'k2': 'dog', 'k3': 'mouse', 'k4': 'fish'}

# %%
dict["k2"]
# Out:
# 'dog'

# %%
dict["k3"]
# Out:
# 'mouse'

# %%
dict["k5"] = "parrot"

# %%
dict
# Out:
# {'k1': 'cat', 'k2': 'dog', 'k3': 'mouse', 'k4': 'fish', 'k5': 'parrot'}

# %%
dict["k2"] = "dog"

# %%
dict
# Out:
# {'k1': 'cat', 'k2': 'dog', 'k3': 'mouse', 'k4': 'fish', 'k5': 'parrot'}

# %%
dep_workers = {"dep_1": "Peter", "dep_2": ["Jenifer", "Michael", "Tommy"]}
dep_workers
# Out:
# {'dep_1': 'Peter', 'dep_2': ['Jenifer', 'Michael', 'Tommy']}

# %%
dep_workers["dep_2"][2]
# Out:
# 'Tommy'

# %%
team = {}
team["Fronted Developer"] = "Pedro"
team["Backend Developer"] = "Epy"
team["CI CD"] = "Roberto"
team["DB"] = "Okan"
team["Ai Engineer"] = "Juliao"
team
# Out:
# {'Fronted Developer': 'Pedro',
#  'Backend Developer': 'Epy',
#  'CI CD': 'Roberto',
#  'DB': 'Okan',
#  'Ai Engineer': 'Juliao'}

# %%
print(team.get("Ai Engineer"))
# Out:
# Juliao

# %%
print(team.get("CEO"))
# Out:
# None
