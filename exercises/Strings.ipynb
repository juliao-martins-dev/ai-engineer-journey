# %%
'Juliao'
# Out:
# 'Juliao'

# %%
"Juliao"
# Out:
# 'Juliao'

# %%
print("Juliao")
# Out:
# Juliao

# %%
x = 10
print(str(x) + " Dollars")
# Out:
# 10 Dollars

# %%
'I\'m fine'
# Out:
# "I'm fine"

# %%
"I'm fine"
# Out:
# "I'm fine"

# %%
'press "Enter"'
# Out:
# 'press "Enter"'

# %%
'Red' ' car'
# Out:
# 'Red car'

# %%
'Red' + ' car'
# Out:
# 'Red car'

# %%
print ('Red', 'car')
# Out:
# Red car

# %%
print(3, 5)
# Out:
# 3 5

# %%
3, 5
# Out:
# (3, 5)

# %%
3, True, "Juliao Martins"
# Out:
# (3, True, 'Juliao Martins')
