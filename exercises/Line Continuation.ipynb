# %%
# this is just a comment!

# %%
3 + 5 * \
9
# Out:
# 48

# %%
# firs define a function with name greeting
def greeting():
    # block of code function print Hello, World in output
    print("Hello, World")


# invoke here
greeting()
# Out:
# Hello, World
