# %% [markdown]
# ## Python Lists Pratice

# %%
participants = ['John', 'Leila', 'Gregory', 'Cate']
participants
# Out:
# ['John', 'Leila', 'Gregory', 'Cate']

# %%
print(participants[1])
# Out:
# Leila

# %%
print(participants[-1])
# Out:
# Cate

# %%
print(participants[-2])
# Out:
# Gregory

# %%
participants[3] = 'Maria'
participants
# Out:
# ['John', 'Leila', 'Gregory', 'Maria']

# %%
participants
# Out:
# ['John', 'Leila', 'Gregory', 'Maria']

# %%
del participants[2]
participants
# Out:
# ['John', 'Leila', 'Maria']

# %%
participants
# Out:
# ['John', 'Leila', 'Maria']

# %%
participants.append('Juliao')
participants
# Out:
# ['John', 'Leila', 'Maria', 'Juliao']

# %%
participants.extend(['Patrick', 'Lary'])
participants
# Out:
# ['John', 'Leila', 'Maria', 'Juliao', 'Patrick', 'Lary']

# %%
print("The first participant is " + participants[0] + ".")
# Out:
# The first participant is John.

# %%
len('Dolphin')
# Out:
# 7

# %%
len(participants)
# Out:
# 6

# %% [markdown]
# **List slicing**

# %%
members = ['Juliao', 'Marcel', 'Lucas', 'Bakita']
members
# Out:
# ['Juliao', 'Marcel', 'Lucas', 'Bakita']

# %%
members[1:3]
# Out:
# ['Marcel', 'Lucas']

# %%
members[:2]
# Out:
# ['Juliao', 'Marcel']

# %%
members[3:]
# Out:
# ['Bakita']

# %%
members[-3:]
# Out:
# ['Marcel', 'Lucas', 'Bakita']

# %%
members.index('Juliao')
# Out:
# 0

# %%
participants
# Out:
# ['John', 'Leila', 'Maria', 'Juliao', 'Patrick', 'Lary']

# %%
people = [members, participants]
people
# Out:
# [['Juliao', 'Marcel', 'Lucas', 'Bakita'],
#  ['John', 'Leila', 'Maria', 'Juliao', 'Patrick', 'Lary']]

# %%
people[0][1]
# Out:
# 'Marcel'

# %%
people[1][2:4]
# Out:
# ['Maria', 'Juliao']

# %%
members
# Out:
# ['Juliao', 'Marcel', 'Lucas', 'Bakita']

# %%
members.sort()
members
# Out:
# ['Bakita', 'Juliao', 'Lucas', 'Marcel']

# %%
members.sort(reverse=True)
members
# Out:
# ['Marcel', 'Lucas', 'Juliao', 'Bakita']
