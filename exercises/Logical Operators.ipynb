# %% [markdown]
# ### Logical Operators

# %% [markdown]
# **Not - And - Or**

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %%
3 > 5 and 20 <= 20
# Out:
# False

# %%
True and not True
# Out:
# False

# %%
False or not True and True
# Out:
# False

# %%
True and not True or True
# Out:
# True

# %% [markdown]
# #### Identity Operators

# %% [markdown]
# **is, is not**

# %%
# 5 is 6 instead use == better than is 5 == 6
r"""
<>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
C:\Users\User\AppData\Local\Temp\ipykernel_8180\2929037671.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
  5 is 6
"""
# Out:
# '\n<>:1: SyntaxWarning: "is" with \'int\' literal. Did you mean "=="?\nC:\\Users\\User\\AppData\\Local\\Temp\\ipykernel_8180\\2929037671.py:1: SyntaxWarning: "is" with \'int\' literal. Did you mean "=="?\n  5 is 6\n'

# %%
5 is not 6
# Out:
# True

# %%
5 is 6
# Out:
# False
