# %% [markdown]
# # Arithmetic Operators

# %%
1 + 2
# Out:
# 3

# %%
3 - 5
# Out:
# -2

# %%
15 / 3
# Out:
# 5.0

# %%
16 / 3
# Out:
# 5.333333333333333

# %%
15 // 3
# Out:
# 5

# %%
16 // 3
# Out:
# 5

# %%
16.0 // 3
# Out:
# 5.0

# %%
16 % 3
# Out:
# 1

# %%
5 * 3
# Out:
# 15

# %%
x = 5 * 3

# %%
x
# Out:
# 15

# %%
5 ** 3
# Out:
# 125
